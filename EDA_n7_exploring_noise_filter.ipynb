# %%
import warnings
warnings.filterwarnings("ignore")

# importing the required packages
import os
import gc
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from scipy.signal import medfilt

# %%
# changing directory and verifying
# %cd /content/drive/MyDrive/DISC_Files/with_cell
# !ls -v
# Out:
# /content/drive/MyDrive/DISC_Files/with_cell
# 111.csv  142.csv  223.csv  263.csv  333.csv  414.csv  438.csv  463.csv	529.csv  556.csv   3311.csv
# 112.csv  143.csv  224.csv  264.csv  334.csv  415.csv  439.csv  464.csv	531.csv  557.csv   4110.csv
# 113.csv  144.csv  225.csv  311.csv  335.csv  416.csv  441.csv  465.csv	532.csv  561.csv   4111.csv
# 114.csv  151.csv  226.csv  312.csv  336.csv  417.csv  442.csv  466.csv	533.csv  562.csv   4210.csv
# 115.csv  152.csv  227.csv  313.csv  337.csv  418.csv  443.csv  467.csv	534.csv  563.csv   4211.csv
# 116.csv  153.csv  231.csv  314.csv  338.csv  419.csv  444.csv  511.csv	535.csv  564.csv   4310.csv
# 117.csv  154.csv  232.csv  315.csv  339.csv  421.csv  445.csv  512.csv	536.csv  565.csv   4311.csv
# 121.csv  161.csv  233.csv  316.csv  341.csv  422.csv  446.csv  513.csv	537.csv  566.csv   4410.csv
# 122.csv  162.csv  234.csv  317.csv  342.csv  423.csv  447.csv  514.csv	538.csv  567.csv   4411.csv
# 123.csv  163.csv  235.csv  318.csv  343.csv  424.csv  448.csv  515.csv	539.csv  571.csv   4510.csv
# 124.csv  164.csv  236.csv  319.csv  344.csv  425.csv  449.csv  516.csv	541.csv  572.csv   4511.csv
# 125.csv  211.csv  237.csv  321.csv  351.csv  426.csv  451.csv  517.csv	542.csv  573.csv   5110.csv
# 126.csv  212.csv  241.csv  322.csv  352.csv  427.csv  452.csv  518.csv	543.csv  574.csv   5111.csv
# 127.csv  213.csv  242.csv  323.csv  353.csv  428.csv  453.csv  519.csv	544.csv  581.csv   5210.csv
# 131.csv  214.csv  243.csv  324.csv  354.csv  429.csv  454.csv  521.csv	545.csv  582.csv   5211.csv
# 132.csv  215.csv  244.csv  325.csv  361.csv  431.csv  455.csv  522.csv	546.csv  2110.csv  5310.csv
# 133.csv  216.csv  251.csv  326.csv  362.csv  432.csv  456.csv  523.csv	547.csv  2111.csv  5311.csv
# 134.csv  217.csv  252.csv  327.csv  363.csv  433.csv  457.csv  524.csv	551.csv  3110.csv
# 135.csv  218.csv  253.csv  328.csv  364.csv  434.csv  458.csv  525.csv	552.csv  3111.csv
# 136.csv  219.csv  254.csv  329.csv  411.csv  435.csv  459.csv  526.csv	553.csv  3210.csv
# 137.csv  221.csv  261.csv  331.csv  412.csv  436.csv  461.csv  527.csv	554.csv  3211.csv
# 141.csv  222.csv  262.csv  332.csv  413.csv  437.csv  462.csv  528.csv	555.csv  3310.csv

# %%
# initializing empty dataframes
corr_df = pd.DataFrame(columns=['Filename',
                                'n',
                                '405 vs 488',
                                '488 vs 633',
                                '405 vs 633',
                                '488 vs (405 - 633)',
                                '405 vs 488 (p)',
                                '488 vs 633 (p)',
                                '405 vs 633 (p)',
                                '488 vs (405 - 633) (p)'])

# %%
# function to do the following:
# creating a ‘label_modified’ column based on the original ‘label’ column.
# if there are 18 consecutive points with 1, it is retained as 1, otherwise, it is changed to 0.
# this is faster than the previous for loops since it uses numpy vectorization
def modify_data(df):

    # make groups
    df['group'] = (df['label'] != df['label'].shift()).cumsum()

    # cummulative count for each group
    df['counter'] = df.groupby('group').cumcount() + 1

    # mark the rows with the cummulative count >= K and label = 1 as True
    df['label_modified'] = (df['label'] == 1) & (df['counter'] >= 18)

    # for each group - check if any of the row is marked as 1, if so, mark all the rows in the group as True, then convert the whole column to 1/0
    df['label_modified'] = df.groupby('group')['label_modified'].transform('any').astype(int)

    # drop intermediate columns
    df.drop(['group', 'counter'], axis=1, inplace=True)

    return df

# %%
# median filter
# it works by replacing each data point in a signal with the median value within a specified window around that data point.
def noise_filter(df, window_size):

  df['405'] = medfilt(df['405'], kernel_size=window_size)
  df['488'] = medfilt(df['488'], kernel_size=window_size)
  df['633'] = medfilt(df['633'], kernel_size=window_size)

  return df

# %%
# function to calculate the correlations
def calc_correlation(df_0, df_1):

  v1 = df_0['405'].corr(df_0['488'])
  v2 = df_0['488'].corr(df_0['633'])
  v3 = df_0['405'].corr(df_0['633'])
  v4 = df_0['488'].corr(df_0['405'] - df_0['633'])

  if 1 in df_0['label_modified'].values:
    v1, v2, v3, v4 = 'NULL', 'NULL', 'NULL', 'NULL'

  v5 = df_1['405'].corr(df_1['488'])
  v6 = df_1['488'].corr(df_1['633'])
  v7 = df_1['405'].corr(df_1['633'])
  v8 = df_1['488'].corr(df_1['405'] - df_1['633'])

  return v1, v2, v3, v4, v5, v6, v7, v8

# %%
index_x = 0

# read files (adjust the range as required)
for i in range(111, 5312):

  filename = f"{i}.csv"
  if os.path.exists(filename):

    # clear memory
    if 'data' in locals():
      del data
      gc.collect()

    # defining column names
    column_names = ['405', '488', '633', 'red', 'green', 'label']

    # define data types for each column - this makes reading faster since python does not have to infer the data type of each column (only slight improvement)
    dtypes = {'405': 'float64', '488': 'float64', '633': 'float64', 'red': 'float64', 'green': 'float64', 'label': 'int64'}

    print(f'Reading in {filename}')
    data = pd.read_csv(filename, header=None, names=column_names, dtype=dtypes)

    # shape of the data
    print(f'Shape of the data is: {data.shape}')

    # with K = 18, create modified label column
    df = modify_data(data)
    # apply the moise filter
    df = noise_filter(df, 9)

    # extracting all sets of 1s into separate groups (each group represents an occurence of a peak)
    df['group'] = (df['label_modified'] != df['label_modified'].shift()).cumsum()
    df_1 = df[df['label_modified'] == 1]
    df_1_groups = df_1.groupby('group')

    # for each group created above, extracting data of equal size with 0s right above an occurence of a peak
    for group_num, group_data_1 in df_1_groups:
      print(group_data_1.shape)
      print('-----')
      index_1_start = group_data_1.index[0]
      index_0_start = group_data_1.index[0] - group_data_1.shape[0]
      group_data_0 = df.loc[index_0_start : index_1_start - 1, ]

      # calculate the correlation for the following: 405 vs 488 ; 488 vs 633 ; 405 vs 633 for without and with peaks
      v1, v2, v3, v4, v5, v6, v7, v8 = calc_correlation(group_data_0, group_data_1)

      # store the values in a dataframe
      corr_df.loc[index_x] = [i, group_data_1.shape[0], v1, v2, v3, v4, v5, v6, v7, v8]
      index_x = index_x + 1

      # clear memory
      del group_data_0, group_data_1
      gc.collect()
# Out:
# Reading in 111.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# Reading in 112.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (29, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# (26, 8)
# -----
# Reading in 113.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# (26, 8)
# -----
# (22, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (33, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# Reading in 114.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# (27, 8)
# -----
# (26, 8)
# -----
# (18, 8)
# -----
# (25, 8)
# -----
# (29, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# Reading in 115.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (24, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# Reading in 116.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# (27, 8)
# -----
# Reading in 117.csv
# Shape of the data is: (3690000, 6)
# (21, 8)
# -----
# (19, 8)
# -----
# (26, 8)
# -----
# (20, 8)
# -----
# Reading in 121.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (31, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# Reading in 122.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# Reading in 123.csv
# Shape of the data is: (5400000, 6)
# (28, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# Reading in 124.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (22, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# Reading in 125.csv
# Shape of the data is: (5400000, 6)
# (27, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (22, 8)
# -----
# Reading in 126.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 127.csv
# Shape of the data is: (3690000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# Reading in 131.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (26, 8)
# -----
# Reading in 132.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 133.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 134.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# Reading in 135.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (28, 8)
# -----
# (20, 8)
# -----
# Reading in 136.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (23, 8)
# -----
# (22, 8)
# -----
# Reading in 137.csv
# Shape of the data is: (3690000, 6)
# (19, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# Reading in 141.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# Reading in 142.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# Reading in 143.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# Reading in 144.csv
# Shape of the data is: (1878000, 6)
# (20, 8)
# -----
# Reading in 151.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 152.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# Reading in 153.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (24, 8)
# -----
# (22, 8)
# -----
# (27, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 154.csv
# Shape of the data is: (1878000, 6)
# (20, 8)
# -----
# Reading in 161.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (21, 8)
# -----
# (29, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 162.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# Reading in 163.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (25, 8)
# -----
# (20, 8)
# -----
# Reading in 164.csv
# Shape of the data is: (1878000, 6)
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 211.csv
# Shape of the data is: (5400000, 6)
# Reading in 212.csv
# Shape of the data is: (5400000, 6)
# (41, 8)
# -----
# Reading in 213.csv
# Shape of the data is: (5400000, 6)
# Reading in 214.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (28, 8)
# -----
# (27, 8)
# -----
# Reading in 215.csv
# Shape of the data is: (5400000, 6)
# (25, 8)
# -----
# Reading in 216.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (20, 8)
# -----
# (26, 8)
# -----
# Reading in 217.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (24, 8)
# -----
# (56, 8)
# -----
# Reading in 218.csv
# Shape of the data is: (5400000, 6)
# Reading in 219.csv
# Shape of the data is: (5400000, 6)
# (35, 8)
# -----
# (61, 8)
# -----
# Reading in 221.csv
# Shape of the data is: (5400000, 6)
# (37, 8)
# -----
# Reading in 222.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# Reading in 223.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# Reading in 224.csv
# Shape of the data is: (5400000, 6)
# (32, 8)
# -----
# (21, 8)
# -----
# Reading in 225.csv
# Shape of the data is: (5400000, 6)
# Reading in 226.csv
# Shape of the data is: (5400000, 6)
# Reading in 227.csv
# Shape of the data is: (3684000, 6)
# Reading in 231.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# Reading in 232.csv
# Shape of the data is: (5400000, 6)
# Reading in 233.csv
# Shape of the data is: (5400000, 6)
# Reading in 234.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (18, 8)
# -----
# (30, 8)
# -----
# Reading in 235.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (22, 8)
# -----
# (20, 8)
# -----
# Reading in 236.csv
# Shape of the data is: (5400000, 6)
# Reading in 237.csv
# Shape of the data is: (3690000, 6)
# (38, 8)
# -----
# Reading in 241.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# Reading in 242.csv
# Shape of the data is: (5400000, 6)
# (34, 8)
# -----
# (34, 8)
# -----
# Reading in 243.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (59, 8)
# -----
# Reading in 244.csv
# Shape of the data is: (1878000, 6)
# Reading in 251.csv
# Shape of the data is: (5400000, 6)
# (31, 8)
# -----
# (18, 8)
# -----
# (28, 8)
# -----
# Reading in 252.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (22, 8)
# -----
# Reading in 253.csv
# Shape of the data is: (5400000, 6)
# Reading in 254.csv
# Shape of the data is: (1878000, 6)
# Reading in 261.csv
# Shape of the data is: (5400000, 6)
# Reading in 262.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# Reading in 263.csv
# Shape of the data is: (5400000, 6)
# (33, 8)
# -----
# Reading in 264.csv
# Shape of the data is: (1878000, 6)
# Reading in 311.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (26, 8)
# -----
# (31, 8)
# -----
# (18, 8)
# -----
# Reading in 312.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (30, 8)
# -----
# Reading in 313.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (28, 8)
# -----
# (33, 8)
# -----
# (19, 8)
# -----
# Reading in 314.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (19, 8)
# -----
# Reading in 315.csv
# Shape of the data is: (5400000, 6)
# (25, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (28, 8)
# -----
# Reading in 316.csv
# Shape of the data is: (5400000, 6)
# (31, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# (28, 8)
# -----
# (19, 8)
# -----
# Reading in 317.csv
# Shape of the data is: (5400000, 6)
# (25, 8)
# -----
# (19, 8)
# -----
# Reading in 318.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (22, 8)
# -----
# Reading in 319.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (32, 8)
# -----
# Reading in 321.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (29, 8)
# -----
# (21, 8)
# -----
# Reading in 322.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (28, 8)
# -----
# Reading in 323.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# (27, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (25, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 324.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 325.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (22, 8)
# -----
# Reading in 326.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (31, 8)
# -----
# (25, 8)
# -----
# (18, 8)
# -----
# (38, 8)
# -----
# (18, 8)
# -----
# (31, 8)
# -----
# Reading in 327.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (20, 8)
# -----
# (26, 8)
# -----
# (24, 8)
# -----
# (25, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# Reading in 328.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (39, 8)
# -----
# (27, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# Reading in 329.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 331.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (20, 8)
# -----
# (33, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (32, 8)
# -----
# Reading in 332.csv
# Shape of the data is: (5400000, 6)
# (27, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (22, 8)
# -----
# Reading in 333.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (30, 8)
# -----
# Reading in 334.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# (29, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (26, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (22, 8)
# -----
# (25, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# Reading in 335.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (22, 8)
# -----
# Reading in 336.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (52, 8)
# -----
# Reading in 337.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# Reading in 338.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 339.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 341.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (23, 8)
# -----
# Reading in 342.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (35, 8)
# -----
# (19, 8)
# -----
# Reading in 343.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# Reading in 344.csv
# Shape of the data is: (1878000, 6)
# (20, 8)
# -----
# Reading in 351.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 352.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 353.csv
# Shape of the data is: (5400000, 6)
# (30, 8)
# -----
# Reading in 354.csv
# Shape of the data is: (1878000, 6)
# (22, 8)
# -----
# (21, 8)
# -----
# Reading in 361.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 362.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# (22, 8)
# -----
# (21, 8)
# -----
# Reading in 363.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (18, 8)
# -----
# (41, 8)
# -----
# (20, 8)
# -----
# (22, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# Reading in 364.csv
# Shape of the data is: (1878000, 6)
# (20, 8)
# -----
# (25, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# Reading in 411.csv
# Shape of the data is: (5400000, 6)
# (39, 8)
# -----
# (46, 8)
# -----
# (18, 8)
# -----
# (31, 8)
# -----
# (18, 8)
# -----
# Reading in 412.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (28, 8)
# -----
# (28, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# Reading in 413.csv
# Shape of the data is: (5400000, 6)
# (32, 8)
# -----
# (30, 8)
# -----
# (27, 8)
# -----
# (24, 8)
# -----
# (24, 8)
# -----
# (59, 8)
# -----
# (34, 8)
# -----
# (23, 8)
# -----
# (29, 8)
# -----
# (77, 8)
# -----
# (34, 8)
# -----
# (36, 8)
# -----
# (31, 8)
# -----
# (31, 8)
# -----
# (37, 8)
# -----
# Reading in 414.csv
# Shape of the data is: (5400000, 6)
# (34, 8)
# -----
# (41, 8)
# -----
# (28, 8)
# -----
# (36, 8)
# -----
# (18, 8)
# -----
# Reading in 415.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (25, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (24, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# Reading in 416.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (22, 8)
# -----
# (21, 8)
# -----
# (25, 8)
# -----
# (27, 8)
# -----
# (23, 8)
# -----
# (28, 8)
# -----
# (29, 8)
# -----
# (26, 8)
# -----
# (18, 8)
# -----
# (28, 8)
# -----
# (29, 8)
# -----
# (28, 8)
# -----
# (31, 8)
# -----
# (31, 8)
# -----
# (30, 8)
# -----
# (29, 8)
# -----
# (96, 8)
# -----
# Reading in 417.csv
# Shape of the data is: (5400000, 6)
# (56, 8)
# -----
# (29, 8)
# -----
# (27, 8)
# -----
# (33, 8)
# -----
# (34, 8)
# -----
# (49, 8)
# -----
# (37, 8)
# -----
# (46, 8)
# -----
# (66, 8)
# -----
# (30, 8)
# -----
# (44, 8)
# -----
# (40, 8)
# -----
# (34, 8)
# -----
# Reading in 418.csv
# Shape of the data is: (5400000, 6)
# (37, 8)
# -----
# (30, 8)
# -----
# (32, 8)
# -----
# (41, 8)
# -----
# (46, 8)
# -----
# (18, 8)
# -----
# (33, 8)
# -----
# (36, 8)
# -----
# (50, 8)
# -----
# (34, 8)
# -----
# (33, 8)
# -----
# (35, 8)
# -----
# (29, 8)
# -----
# (29, 8)
# -----
# (37, 8)
# -----
# (53, 8)
# -----
# (37, 8)
# -----
# (34, 8)
# -----
# (27, 8)
# -----
# (27, 8)
# -----
# Reading in 419.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (29, 8)
# -----
# (28, 8)
# -----
# (29, 8)
# -----
# (41, 8)
# -----
# (24, 8)
# -----
# (25, 8)
# -----
# (19, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# Reading in 421.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (27, 8)
# -----
# (24, 8)
# -----
# (20, 8)
# -----
# (33, 8)
# -----
# (22, 8)
# -----
# (24, 8)
# -----
# (27, 8)
# -----
# (24, 8)
# -----
# (22, 8)
# -----
# Reading in 422.csv
# Shape of the data is: (5400000, 6)
# (45, 8)
# -----
# (37, 8)
# -----
# (22, 8)
# -----
# (37, 8)
# -----
# (43, 8)
# -----
# (27, 8)
# -----
# (44, 8)
# -----
# (29, 8)
# -----
# (28, 8)
# -----
# (28, 8)
# -----
# (29, 8)
# -----
# (38, 8)
# -----
# (32, 8)
# -----
# (31, 8)
# -----
# (35, 8)
# -----
# (28, 8)
# -----
# (30, 8)
# -----
# (28, 8)
# -----
# (38, 8)
# -----
# (28, 8)
# -----
# Reading in 423.csv
# Shape of the data is: (5400000, 6)
# (30, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# Reading in 424.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (25, 8)
# -----
# (28, 8)
# -----
# (18, 8)
# -----
# (32, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# Reading in 425.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (26, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# (37, 8)
# -----
# (40, 8)
# -----
# (23, 8)
# -----
# (23, 8)
# -----
# (33, 8)
# -----
# (31, 8)
# -----
# (31, 8)
# -----
# (27, 8)
# -----
# (25, 8)
# -----
# (36, 8)
# -----
# (22, 8)
# -----
# Reading in 426.csv
# Shape of the data is: (5400000, 6)
# (32, 8)
# -----
# (39, 8)
# -----
# (44, 8)
# -----
# (33, 8)
# -----
# (47, 8)
# -----
# (29, 8)
# -----
# (31, 8)
# -----
# (32, 8)
# -----
# (35, 8)
# -----
# Reading in 427.csv
# Shape of the data is: (5400000, 6)
# (35, 8)
# -----
# (31, 8)
# -----
# (33, 8)
# -----
# (45, 8)
# -----
# (18, 8)
# -----
# (26, 8)
# -----
# (26, 8)
# -----
# Reading in 428.csv
# Shape of the data is: (5400000, 6)
# (33, 8)
# -----
# (24, 8)
# -----
# (29, 8)
# -----
# (24, 8)
# -----
# (28, 8)
# -----
# (22, 8)
# -----
# (25, 8)
# -----
# (27, 8)
# -----
# (26, 8)
# -----
# (30, 8)
# -----
# (23, 8)
# -----
# (37, 8)
# -----
# (29, 8)
# -----
# (27, 8)
# -----
# (24, 8)
# -----
# (27, 8)
# -----
# (26, 8)
# -----
# Reading in 429.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (25, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# Reading in 431.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (45, 8)
# -----
# Reading in 432.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (24, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# (23, 8)
# -----
# (22, 8)
# -----
# (24, 8)
# -----
# (24, 8)
# -----
# (20, 8)
# -----
# (24, 8)
# -----
# (30, 8)
# -----
# Reading in 433.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (24, 8)
# -----
# (33, 8)
# -----
# (51, 8)
# -----
# (31, 8)
# -----
# Reading in 434.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# Reading in 435.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# (29, 8)
# -----
# (25, 8)
# -----
# (22, 8)
# -----
# (23, 8)
# -----
# (29, 8)
# -----
# (23, 8)
# -----
# Reading in 436.csv
# Shape of the data is: (5400000, 6)
# (28, 8)
# -----
# (31, 8)
# -----
# (25, 8)
# -----
# (29, 8)
# -----
# (21, 8)
# -----
# (31, 8)
# -----
# (23, 8)
# -----
# (44, 8)
# -----
# (18, 8)
# -----
# (42, 8)
# -----
# (45, 8)
# -----
# (36, 8)
# -----
# (27, 8)
# -----
# Reading in 437.csv
# Shape of the data is: (5400000, 6)
# (28, 8)
# -----
# (36, 8)
# -----
# (27, 8)
# -----
# (24, 8)
# -----
# (51, 8)
# -----
# (28, 8)
# -----
# (30, 8)
# -----
# (25, 8)
# -----
# (24, 8)
# -----
# Reading in 438.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# (25, 8)
# -----
# (23, 8)
# -----
# (22, 8)
# -----
# (34, 8)
# -----
# (38, 8)
# -----
# (46, 8)
# -----
# (32, 8)
# -----
# (19, 8)
# -----
# (27, 8)
# -----
# (20, 8)
# -----
# (31, 8)
# -----
# (24, 8)
# -----
# (25, 8)
# -----
# (30, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (33, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 439.csv
# Shape of the data is: (5400000, 6)
# (33, 8)
# -----
# (35, 8)
# -----
# (32, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (26, 8)
# -----
# Reading in 441.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# Reading in 442.csv
# Shape of the data is: (5400000, 6)
# (31, 8)
# -----
# Reading in 443.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (22, 8)
# -----
# (24, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# Reading in 444.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# Reading in 445.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (22, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# Reading in 446.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (31, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# Reading in 447.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (20, 8)
# -----
# (29, 8)
# -----
# Reading in 448.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# Reading in 449.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# Reading in 451.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (18, 8)
# -----
# Reading in 452.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# Reading in 453.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (22, 8)
# -----
# (20, 8)
# -----
# (28, 8)
# -----
# Reading in 454.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# (44, 8)
# -----
# (26, 8)
# -----
# (42, 8)
# -----
# (27, 8)
# -----
# Reading in 455.csv
# Shape of the data is: (5400000, 6)
# (25, 8)
# -----
# (23, 8)
# -----
# (26, 8)
# -----
# (27, 8)
# -----
# (38, 8)
# -----
# Reading in 456.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (33, 8)
# -----
# (29, 8)
# -----
# Reading in 457.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (21, 8)
# -----
# Reading in 458.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (20, 8)
# -----
# (24, 8)
# -----
# (26, 8)
# -----
# (22, 8)
# -----
# (25, 8)
# -----
# (33, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# Reading in 459.csv
# Shape of the data is: (5400000, 6)
# (32, 8)
# -----
# (35, 8)
# -----
# (23, 8)
# -----
# (31, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (33, 8)
# -----
# (29, 8)
# -----
# (22, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (30, 8)
# -----
# (27, 8)
# -----
# (32, 8)
# -----
# Reading in 461.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# Reading in 462.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (23, 8)
# -----
# (22, 8)
# -----
# (22, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (41, 8)
# -----
# (20, 8)
# -----
# Reading in 463.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# Reading in 464.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# (51, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (23, 8)
# -----
# (26, 8)
# -----
# (30, 8)
# -----
# (24, 8)
# -----
# Reading in 465.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (31, 8)
# -----
# (25, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# (26, 8)
# -----
# (23, 8)
# -----
# Reading in 466.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (22, 8)
# -----
# (21, 8)
# -----
# (26, 8)
# -----
# (22, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# (21, 8)
# -----
# (37, 8)
# -----
# (20, 8)
# -----
# (37, 8)
# -----
# (19, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# Reading in 467.csv
# Shape of the data is: (5400000, 6)
# Reading in 511.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (26, 8)
# -----
# (59, 8)
# -----
# (35, 8)
# -----
# (57, 8)
# -----
# (31, 8)
# -----
# (67, 8)
# -----
# (30, 8)
# -----
# (35, 8)
# -----
# (37, 8)
# -----
# Reading in 512.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (79, 8)
# -----
# (62, 8)
# -----
# (27, 8)
# -----
# (66, 8)
# -----
# (24, 8)
# -----
# Reading in 513.csv
# Shape of the data is: (5400000, 6)
# (32, 8)
# -----
# (26, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (25, 8)
# -----
# Reading in 514.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (21, 8)
# -----
# Reading in 515.csv
# Shape of the data is: (5400000, 6)
# (35, 8)
# -----
# (45, 8)
# -----
# (36, 8)
# -----
# (30, 8)
# -----
# Reading in 516.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (22, 8)
# -----
# (28, 8)
# -----
# (29, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (24, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# Reading in 517.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (29, 8)
# -----
# (23, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# Reading in 518.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (20, 8)
# -----
# (25, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (28, 8)
# -----
# Reading in 519.csv
# Shape of the data is: (5400000, 6)
# (25, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 521.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# Reading in 522.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (24, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# Reading in 523.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (24, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# Reading in 524.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# (32, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (26, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (26, 8)
# -----
# (18, 8)
# -----
# Reading in 525.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# (26, 8)
# -----
# (19, 8)
# -----
# (28, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (31, 8)
# -----
# Reading in 526.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (20, 8)
# -----
# (24, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# Reading in 527.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# (25, 8)
# -----
# (27, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# Reading in 528.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (28, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 529.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# Reading in 531.csv
# Shape of the data is: (5400000, 6)
# (23, 8)
# -----
# Reading in 532.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# Reading in 533.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# Reading in 534.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (25, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# Reading in 535.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (24, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (24, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# Reading in 536.csv
# Shape of the data is: (5400000, 6)
# (28, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# Reading in 537.csv
# Shape of the data is: (5400000, 6)
# (29, 8)
# -----
# (20, 8)
# -----
# Reading in 538.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (24, 8)
# -----
# Reading in 539.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# Reading in 541.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# Reading in 542.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# Reading in 543.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# Reading in 544.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (27, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# Reading in 545.csv
# Shape of the data is: (5400000, 6)
# (24, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 546.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# Reading in 547.csv
# Shape of the data is: (3690000, 6)
# (21, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# Reading in 551.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (20, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# Reading in 552.csv
# Shape of the data is: (5400000, 6)
# (22, 8)
# -----
# (21, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# (19, 8)
# -----
# (21, 8)
# -----
# (21, 8)
# -----
# (26, 8)
# -----
# (18, 8)
# -----
# Reading in 553.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (22, 8)
# -----
# (24, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# Reading in 554.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# Reading in 555.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (26, 8)
# -----
# (27, 8)
# -----
# (18, 8)
# -----
# Reading in 556.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (25, 8)
# -----
# (18, 8)
# -----
# Reading in 557.csv
# Shape of the data is: (3684000, 6)
# (26, 8)
# -----
# (23, 8)
# -----
# Reading in 561.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# Reading in 562.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (28, 8)
# -----
# (27, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# Reading in 563.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (28, 8)
# -----
# Reading in 564.csv
# Shape of the data is: (5400000, 6)
# (25, 8)
# -----
# (20, 8)
# -----
# (20, 8)
# -----
# Reading in 565.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (20, 8)
# -----
# Reading in 566.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# Reading in 567.csv
# Shape of the data is: (3690000, 6)
# (18, 8)
# -----
# Reading in 571.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (20, 8)
# -----
# Reading in 572.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (19, 8)
# -----
# Reading in 573.csv
# Shape of the data is: (5400000, 6)
# Reading in 574.csv
# Shape of the data is: (1878000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# Reading in 581.csv
# Shape of the data is: (5400000, 6)
# Reading in 582.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# Reading in 2110.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# Reading in 2111.csv
# Shape of the data is: (96000, 6)
# Reading in 3110.csv
# Shape of the data is: (5400000, 6)
# Reading in 3111.csv
# Shape of the data is: (90000, 6)
# Reading in 3210.csv
# Shape of the data is: (5400000, 6)
# (18, 8)
# -----
# (23, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (22, 8)
# -----
# Reading in 3211.csv
# Shape of the data is: (66000, 6)
# Reading in 3310.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (19, 8)
# -----
# (20, 8)
# -----
# (21, 8)
# -----
# Reading in 3311.csv
# Shape of the data is: (90000, 6)
# Reading in 4110.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (22, 8)
# -----
# Reading in 4111.csv
# Shape of the data is: (96000, 6)
# Reading in 4210.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (21, 8)
# -----
# Reading in 4211.csv
# Shape of the data is: (96000, 6)
# Reading in 4310.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (23, 8)
# -----
# (20, 8)
# -----
# (19, 8)
# -----
# (30, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (27, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# Reading in 4311.csv
# Shape of the data is: (96000, 6)
# Reading in 4410.csv
# Shape of the data is: (5400000, 6)
# (21, 8)
# -----
# (24, 8)
# -----
# (20, 8)
# -----
# (33, 8)
# -----
# (22, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (19, 8)
# -----
# (25, 8)
# -----
# (25, 8)
# -----
# (19, 8)
# -----
# (27, 8)
# -----
# (33, 8)
# -----
# Reading in 4411.csv
# Shape of the data is: (96000, 6)
# Reading in 4510.csv
# Shape of the data is: (5400000, 6)
# (26, 8)
# -----
# (47, 8)
# -----
# (19, 8)
# -----
# (26, 8)
# -----
# (19, 8)
# -----
# (29, 8)
# -----
# (30, 8)
# -----
# (25, 8)
# -----
# (25, 8)
# -----
# Reading in 4511.csv
# Shape of the data is: (96000, 6)
# Reading in 5110.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (19, 8)
# -----
# (36, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# Reading in 5111.csv
# Shape of the data is: (96000, 6)
# Reading in 5210.csv
# Shape of the data is: (5400000, 6)
# (20, 8)
# -----
# (21, 8)
# -----
# (21, 8)
# -----
# (18, 8)
# -----
# (23, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (18, 8)
# -----
# (22, 8)
# -----
# (18, 8)
# -----
# Reading in 5211.csv
# Shape of the data is: (96000, 6)
# Reading in 5310.csv
# Shape of the data is: (5400000, 6)
# (19, 8)
# -----
# (19, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# (18, 8)
# -----
# (20, 8)
# -----
# Reading in 5311.csv
# Shape of the data is: (96000, 6)

# %%
# write into a file
corr_df.to_csv('/content/drive/MyDrive/DISC_Files/pearson_correlations_with_equal_n_and_nf.csv', index=False)

# %%
# reading in the correlation file - pearson_correlations_with_equal_n.csv
corr_df = pd.read_csv('/content/drive/MyDrive/DISC_Files/pearson_correlations_with_equal_n_and_nf.csv')
corr_df.head()
# Out:
#    Filename     n  405 vs 488  488 vs 633  405 vs 633  488 vs (405 - 633)  \
# 0     111.0  23.0    0.354616    0.777630   -0.133970           -0.653793
# 1     111.0  22.0    0.154425    0.903505    0.204284           -0.900654
# 2     111.0  18.0    0.878663    0.061230   -0.148005            0.514320
# 3     111.0  19.0    0.839541    0.895207    0.841448           -0.879005
# 4     111.0  18.0   -0.772140    0.880829   -0.825689           -0.877357
#
#    405 vs 488 (p)  488 vs 633 (p)  405 vs 633 (p)  488 vs (405 - 633) (p)
# 0        0.703465        0.866250        0.704819                0.575821
# 1        0.432378        0.866269        0.517510               -0.712548
# 2        0.018290        0.808980       -0.519861               -0.132462
# 3        0.501226        0.639159       -0.151214                0.261821
# 4       -0.386988        0.747016       -0.313732               -0.642296

# %%
# print the minimum values of each column
print("Minimum values:")
print(corr_df.min().to_string(float_format="{:.2f}".format))

# print the maximum values of each column
print("\nMaximum values:")
print(corr_df.max().to_string(float_format="{:.2f}".format))
# Out:
# Minimum values:
# Filename                 111.00
# n                         18.00
# 405 vs 488                -0.98
# 488 vs 633                -0.80
# 405 vs 633                -0.98
# 488 vs (405 - 633)        -0.99
# 405 vs 488 (p)            -0.99
# 488 vs 633 (p)            -0.90
# 405 vs 633 (p)            -0.97
# 488 vs (405 - 633) (p)    -0.99
#
# Maximum values:
# Filename                 5310.00
# n                          96.00
# 405 vs 488                  1.00
# 488 vs 633                  1.00
# 405 vs 633                  1.00
# 488 vs (405 - 633)          1.00
# 405 vs 488 (p)              0.98
# 488 vs 633 (p)              1.00
# 405 vs 633 (p)              0.98
# 488 vs (405 - 633) (p)      0.98

# %%
# 405 v 488
# plotting the histogram for 405 vs 488 (p) correlations
sns.histplot(data=corr_df, x='405 vs 488 (p)', kde=True, color='red', label='405 vs 488 (p)')

# plotting the histogram for 405 vs 488 correlations
sns.histplot(data=corr_df, x='405 vs 488', kde=True, color='blue', label='405 vs 488')

# setting labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Correlation Values')
plt.grid(True)

# adding legend
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 488 vs 633
# plotting the histogram for 488 vs 633 (p) correlations
sns.histplot(data=corr_df, x='488 vs 633 (p)', kde=True, color='red', label='488 vs 633 (p)')

# plotting the histogram for 488 vs 633 correlations
sns.histplot(data=corr_df, x='488 vs 633', kde=True, color='blue', label='488 vs 633')

# setting labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Correlation Values')
plt.grid(True)

# adding legend
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 405 vs 633
# plotting the histogram for 405 vs 633 (p) correlations
sns.histplot(data=corr_df, x='405 vs 633 (p)', kde=True, color='red', label='405 vs 633 (p)')

# plotting the histogram for 405 vs 633 correlations
sns.histplot(data=corr_df, x='405 vs 633', kde=True, color='blue', label='405 vs 633')

# setting labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Correlation Values')
plt.grid(True)

# adding legend
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 488 vs (405 - 633)
# plotting the histogram for 488 vs (405 - 633) (p) correlations
sns.histplot(data=corr_df, x='488 vs (405 - 633) (p)', kde=True, color='red', label='488 vs (405 - 633) (p)')

# plotting the histogram for 488 vs (405 - 633) correlations
sns.histplot(data=corr_df, x='488 vs (405 - 633)', kde=True, color='blue', label='488 vs (405 - 633)')

# setting labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Correlation Values')
plt.grid(True)

# adding legend
plt.legend()

plt.tight_layout()
plt.show()
