# %%
import warnings
warnings.filterwarnings("ignore")

# importing the required packages
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# changing directory and verifying
# %cd /content/drive/MyDrive/DISC_Files/with_cell
# !ls
# Out:
# /content/drive/MyDrive/DISC_Files/with_cell
# 111.csv  144.csv   225.csv   311.csv   333.csv	 414.csv   436.csv   458.csv   523.csv	 547.csv
# 112.csv  151.csv   226.csv   312.csv   334.csv	 415.csv   437.csv   459.csv   524.csv	 551.csv
# 113.csv  152.csv   227.csv   313.csv   335.csv	 416.csv   438.csv   461.csv   525.csv	 552.csv
# 114.csv  153.csv   231.csv   314.csv   336.csv	 417.csv   439.csv   462.csv   526.csv	 553.csv
# 115.csv  154.csv   232.csv   315.csv   337.csv	 418.csv   4410.csv  463.csv   527.csv	 554.csv
# 116.csv  161.csv   233.csv   316.csv   338.csv	 419.csv   4411.csv  464.csv   528.csv	 555.csv
# 117.csv  162.csv   234.csv   317.csv   339.csv	 4210.csv  441.csv   465.csv   529.csv	 556.csv
# 121.csv  163.csv   235.csv   318.csv   341.csv	 4211.csv  442.csv   466.csv   5310.csv  557.csv
# 122.csv  164.csv   236.csv   319.csv   342.csv	 421.csv   443.csv   467.csv   5311.csv  561.csv
# ...

# %%
dfs = []

# read files (adjust the range as required), add the filename as a column, append the dataframes to a list
for i in range(111, 112):
    filename = f"{i}.csv"
    if os.path.exists(filename):
      print(f'Reading in {filename}')
      print('---')
      df = pd.read_csv(filename, header=None)
      # adding columns names
      df.columns = ['405', '488', '633', 'red', 'green', 'label']
      df['file_name'] = i
      dfs.append(df)

# concat all the dataframes into one
data = pd.concat(dfs, ignore_index=True)

# shape of the data
print(f'Shape of the data is: {data.shape}')

# viewing the data
print(data.head())
# Out:
# Reading in 111.csv
# ---
# Shape of the data is: (5400000, 7)
#         405       488       633  red     green  label  file_name
# 0  0.008535 -0.002965 -0.002028  0.0  0.013094      0        111
# 1  0.005164 -0.004470  0.000230  0.0  0.021478      0        111
# 2  0.004839 -0.006207  0.001352  0.0  0.029380      0        111
# 3  0.009197 -0.007472  0.002347  0.0  0.035826      0        111
# 4  0.016611 -0.007011  0.004466  0.0  0.038059      0        111

# %%
# print the minimum values of each column
print("Minimum values:")
print(data.min())

# print the maximum values of each column
print("\nMaximum values:")
print(data.max())
# Out:
# Minimum values:
# 405           -0.032464
# 488           -0.031587
# 633           -0.060599
# red            0.000000
# green          0.000000
# label          0.000000
# file_name    111.000000
# dtype: float64
#
# Maximum values:
# 405            0.473276
# 488            0.149332
# 633            0.376739
# red            0.116079
# green          4.083605
# label          1.000000
# file_name    111.000000
# dtype: float64

# %%
# choose the filename for plotting
to_plot = 111

# create a data subset for plotting
data_plot = data[data['file_name'] == to_plot]

# %%
# plotting 405 frequency
plt.figure(figsize=(4,4))
plt.plot(data_plot['405'], color = 'purple')
plt.grid(True)
plt.show()

# %%
# plotting 488 frequency
plt.figure(figsize=(4,4))
plt.plot(data_plot['488'], color = 'blue')
plt.grid(True)
plt.show()

# %%
# plotting 633 frequency
plt.figure(figsize=(4,4))
plt.plot(data_plot['633'], color = 'red')
plt.grid(True)
plt.show()

# %%
# plotting green signal
plt.figure(figsize=(4,4))
plt.plot(data_plot['green'], color = 'green')
plt.grid(True)
plt.show()

# %%
# 405 frequency vs green signal
plt.figure(figsize=(4,4))
plt.scatter(data_plot['405'], data_plot['green'], color = 'black', s=10)
plt.xlabel('405')
plt.ylabel('green')
plt.grid(True)
plt.show()

# %%
# 488 frequency vs green signal
plt.figure(figsize=(4,4))
plt.scatter(data_plot['488'], data_plot['green'], color = 'black', s=10)
plt.xlabel('488')
plt.ylabel('green')
plt.grid(True)
plt.show()

# %%
# 633 frequency vs green signal
plt.figure(figsize=(4,4))
plt.scatter(data_plot['633'], data_plot['green'], color = 'black', s=10)
plt.xlabel('633')
plt.ylabel('green')
plt.grid(True)
plt.show()

# %%
# creating subsets for plotting
data_plot_0 = data_plot[data_plot['label'] == 0]
data_plot_1 = data_plot[data_plot['label'] == 1]

# %%
# 405 frequency vs green signal

# creating subplots
fig, axs = plt.subplots(1, 2, figsize=(8,4), sharex = True, sharey = True)

# plot for category 0
axs[0].scatter(data_plot_0['405'], data_plot_0['green'], color='black', s=10)
axs[0].set_xlabel('405')
axs[0].set_ylabel('green')
axs[0].grid(True)
axs[0].set_title('Without Peaks')

# plot for category 1
axs[1].scatter(data_plot_1['405'], data_plot_1['green'], color='black', s=10)
axs[1].set_xlabel('405')
axs[1].set_ylabel('green')
axs[1].grid(True)
axs[1].set_title('With Peaks')

plt.tight_layout()
plt.show()

# %%
# 488 frequency vs green signal

# creating subplots
fig, axs = plt.subplots(1, 2, figsize=(8,4), sharex = True, sharey = True)

# plot for category 0
axs[0].scatter(data_plot_0['488'], data_plot_0['green'], color='black', s=10)
axs[0].set_xlabel('488')
axs[0].set_ylabel('green')
axs[0].grid(True)
axs[0].set_title('Without Peaks')

# plot for category 1
axs[1].scatter(data_plot_1['488'], data_plot_1['green'], color='black', s=10)
axs[1].set_xlabel('488')
axs[1].set_ylabel('green')
axs[1].grid(True)
axs[1].set_title('With Peaks')

plt.tight_layout()
plt.show()

# %%
# 633 frequency vs green signal

# creating subplots
fig, axs = plt.subplots(1, 2, figsize=(8,4), sharex = True, sharey = True)

# plot for category 0
axs[0].scatter(data_plot_0['633'], data_plot_0['green'], color='black', s=10)
axs[0].set_xlabel('633')
axs[0].set_ylabel('green')
axs[0].grid(True)
axs[0].set_title('Without Peaks')

# plot for category 1
axs[1].scatter(data_plot_1['633'], data_plot_1['green'], color='black', s=10)
axs[1].set_xlabel('633')
axs[1].set_ylabel('green')
axs[1].grid(True)
axs[1].set_title('With Peaks')

plt.tight_layout()
plt.show()

# %%
data_plot['label'].value_counts()
# Out:
# label
# 0    5387833
# 1      12167
# Name: count, dtype: int64

# %%
# creating a ‘label_modified’ column based on the original ‘label’ column.
# if there are 18 consecutive points with 1, it is retained as 1, otherwise, it is changed to 0.
counter = 0
data_plot.loc[:, 'label_modified'] = 0

# iterate through the dataframe rows
for index, row in data_plot.iterrows():
  if row['label'] == 1:
    counter += 1
  else:
    if counter >= 18:
      data_plot.loc[index - counter:index - 1, 'label_modified'] = 1
    counter = 0

# %%
data_plot['label_modified'].value_counts()
# Out:
# label_modified
# 0    5399900
# 1        100
# Name: count, dtype: int64

# %%
# creating subsets for plotting
data_plot_0 = data_plot[data_plot['label_modified'] == 0]
data_plot_1 = data_plot[data_plot['label_modified'] == 1]

# %%
# 405 frequency vs green signal

# creating subplots
fig, axs = plt.subplots(1, 2, figsize=(8,4), sharex = True, sharey = True)

# plot for category 0
axs[0].scatter(data_plot_0['405'], data_plot_0['green'], color='black', s=10)
axs[0].set_xlabel('405')
axs[0].set_ylabel('green')
axs[0].grid(True)
axs[0].set_title('Without Peaks (Modified)')

# plot for category 1
axs[1].scatter(data_plot_1['405'], data_plot_1['green'], color='black', s=10)
axs[1].set_xlabel('405')
axs[1].set_ylabel('green')
axs[1].grid(True)
axs[1].set_title('With Peaks (Modified)')

plt.tight_layout()
plt.show()

# %%
# 488 frequency vs green signal

# creating subplots
fig, axs = plt.subplots(1, 2, figsize=(8,4), sharex = True, sharey = True)

# plot for category 0
axs[0].scatter(data_plot_0['488'], data_plot_0['green'], color='black', s=10)
axs[0].set_xlabel('488')
axs[0].set_ylabel('green')
axs[0].grid(True)
axs[0].set_title('Without Peaks (Modified)')

# plot for category 1
axs[1].scatter(data_plot_1['488'], data_plot_1['green'], color='black', s=10)
axs[1].set_xlabel('488')
axs[1].set_ylabel('green')
axs[1].grid(True)
axs[1].set_title('With Peaks (Modified)')

plt.tight_layout()
plt.show()

# %%
# 633 frequency vs green signal

# creating subplots
fig, axs = plt.subplots(1, 2, figsize=(8,4), sharex = True, sharey = True)

# plot for category 0
axs[0].scatter(data_plot_0['633'], data_plot_0['green'], color='black', s=10)
axs[0].set_xlabel('633')
axs[0].set_ylabel('green')
axs[0].grid(True)
axs[0].set_title('Without Peaks (Modified)')

# plot for category 1
axs[1].scatter(data_plot_1['633'], data_plot_1['green'], color='black', s=10)
axs[1].set_xlabel('633')
axs[1].set_ylabel('green')
axs[1].grid(True)
axs[1].set_title('With Peaks (Modified)')

plt.tight_layout()
plt.show()
