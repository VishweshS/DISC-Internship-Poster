# %%
import warnings
warnings.filterwarnings("ignore")

# importing the required packages
import os
import gc
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# changing directory and verifying
# %cd /content/drive/MyDrive/DISC_Files/with_cell
# !ls -v
# Out:
# /content/drive/MyDrive/DISC_Files/with_cell
# 111.csv  142.csv  223.csv  263.csv  333.csv  414.csv  438.csv  463.csv	529.csv  556.csv   3311.csv
# 112.csv  143.csv  224.csv  264.csv  334.csv  415.csv  439.csv  464.csv	531.csv  557.csv   4110.csv
# 113.csv  144.csv  225.csv  311.csv  335.csv  416.csv  441.csv  465.csv	532.csv  561.csv   4111.csv
# 114.csv  151.csv  226.csv  312.csv  336.csv  417.csv  442.csv  466.csv	533.csv  562.csv   4210.csv
# 115.csv  152.csv  227.csv  313.csv  337.csv  418.csv  443.csv  467.csv	534.csv  563.csv   4211.csv
# 116.csv  153.csv  231.csv  314.csv  338.csv  419.csv  444.csv  511.csv	535.csv  564.csv   4310.csv
# 117.csv  154.csv  232.csv  315.csv  339.csv  421.csv  445.csv  512.csv	536.csv  565.csv   4311.csv
# 121.csv  161.csv  233.csv  316.csv  341.csv  422.csv  446.csv  513.csv	537.csv  566.csv   4410.csv
# 122.csv  162.csv  234.csv  317.csv  342.csv  423.csv  447.csv  514.csv	538.csv  567.csv   4411.csv
# 123.csv  163.csv  235.csv  318.csv  343.csv  424.csv  448.csv  515.csv	539.csv  571.csv   4510.csv
# 124.csv  164.csv  236.csv  319.csv  344.csv  425.csv  449.csv  516.csv	541.csv  572.csv   4511.csv
# 125.csv  211.csv  237.csv  321.csv  351.csv  426.csv  451.csv  517.csv	542.csv  573.csv   5110.csv
# 126.csv  212.csv  241.csv  322.csv  352.csv  427.csv  452.csv  518.csv	543.csv  574.csv   5111.csv
# 127.csv  213.csv  242.csv  323.csv  353.csv  428.csv  453.csv  519.csv	544.csv  581.csv   5210.csv
# 131.csv  214.csv  243.csv  324.csv  354.csv  429.csv  454.csv  521.csv	545.csv  582.csv   5211.csv
# 132.csv  215.csv  244.csv  325.csv  361.csv  431.csv  455.csv  522.csv	546.csv  2110.csv  5310.csv
# 133.csv  216.csv  251.csv  326.csv  362.csv  432.csv  456.csv  523.csv	547.csv  2111.csv  5311.csv
# 134.csv  217.csv  252.csv  327.csv  363.csv  433.csv  457.csv  524.csv	551.csv  3110.csv
# 135.csv  218.csv  253.csv  328.csv  364.csv  434.csv  458.csv  525.csv	552.csv  3111.csv
# 136.csv  219.csv  254.csv  329.csv  411.csv  435.csv  459.csv  526.csv	553.csv  3210.csv
# 137.csv  221.csv  261.csv  331.csv  412.csv  436.csv  461.csv  527.csv	554.csv  3211.csv
# 141.csv  222.csv  262.csv  332.csv  413.csv  437.csv  462.csv  528.csv	555.csv  3310.csv

# %%
# initializing empty dataframes
corr_df = pd.DataFrame(columns=['Filename', 'n1', 'n2', '405 vs 488', '488 vs 633', '405 vs 633', '405 vs 488 (p)', '488 vs 633 (p)', '405 vs 633 (p)'])

# %%
# function to do the following:
# creating a ‘label_modified’ column based on the original ‘label’ column.
# if there are 18 consecutive points with 1, it is retained as 1, otherwise, it is changed to 0.
# this is faster than the previous for loops since it uses numpy vectorization
def modify_data(df):

    # make groups
    df['group'] = (df['label'] != df['label'].shift()).cumsum()

    # cummulative count for each group
    df['counter'] = df.groupby('group').cumcount() + 1

    # mark the rows with the cummulative count >= K and label = 1 as True
    df['label_modified'] = (df['label'] == 1) & (df['counter'] >= 18)

    # for each group - check if any of the row is marked as 1, if so, mark all the rows in the group as True, then convert the whole column to 1/0
    df['label_modified'] = df.groupby('group')['label_modified'].transform('any').astype(int)

    # drop intermediate columns
    df.drop(['group', 'counter'], axis=1, inplace=True)

    print(df['label_modified'].value_counts())
    print('---')

    # creating subsets for analysis
    df_0 = df[df['label_modified'] == 0]
    df_1 = df[df['label_modified'] == 1]

    return df_0, df_1

# %%
# function to calculate the correlations
def calc_correlation(df_0, df_1):

  v1 = df_0['405'].corr(df_0['488'], method='spearman')
  v2 = df_0['488'].corr(df_0['633'], method='spearman')
  v3 = df_0['405'].corr(df_0['633'], method='spearman')

  v4 = df_1['405'].corr(df_1['488'], method='spearman')
  v5 = df_1['488'].corr(df_1['633'], method='spearman')
  v6 = df_1['405'].corr(df_1['633'], method='spearman')

  return v1, v2, v3, v4, v5, v6

# %%
index_x = -1

# read files (adjust the range as required)
for i in range(111, 5312):

  index_x = index_x + 1

  filename = f"{i}.csv"
  if os.path.exists(filename):

    # clear memory
    if 'df' in locals():
      del df
      gc.collect()

    # defining column names
    column_names = ['405', '488', '633', 'red', 'green', 'label']

    # define data types for each column - this makes reading faster since python does not have to infer the data type of each column (only slight improvement)
    dtypes = {'405': 'float64', '488': 'float64', '633': 'float64', 'red': 'float64', 'green': 'float64', 'label': 'int64'}

    print(f'Reading in {filename}')
    df = pd.read_csv(filename, header=None, names=column_names, dtype=dtypes)

    # shape of the data
    print(f'Shape of the data is: {df.shape}')

    # with K = 18, create subsets
    df_0, df_1 = modify_data(df)
    # the sample sizes
    n1 = df_0.shape[0]
    n2 = df_1.shape[0]

    # calculate the correlation for the following: 405 vs 488 ; 488 vs 633 ; 405 vs 633 for without and with peaks
    v1, v2, v3, v4, v5, v6 = calc_correlation(df_0, df_1)

    # store the values in a dataframe
    corr_df.loc[index_x] = [i, n1, n2, v1, v2, v3, v4, v5, v6]

    # clear memory
    del df_0, df_1
    gc.collect()
# Out:
# Reading in 111.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399900
# 1        100
# Name: count, dtype: int64
# ---
# Reading in 112.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399765
# 1        235
# Name: count, dtype: int64
# ---
# Reading in 113.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399704
# 1        296
# Name: count, dtype: int64
# ---
# Reading in 114.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399736
# 1        264
# Name: count, dtype: int64
# ---
# Reading in 115.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399806
# 1        194
# Name: count, dtype: int64
# ---
# Reading in 116.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399799
# 1        201
# Name: count, dtype: int64
# ---
# Reading in 117.csv
# Shape of the data is: (3690000, 6)
# label_modified
# 0    3689914
# 1         86
# Name: count, dtype: int64
# ---
# Reading in 121.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399908
# 1         92
# Name: count, dtype: int64
# ---
# Reading in 122.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399844
# 1        156
# Name: count, dtype: int64
# ---
# Reading in 123.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399735
# 1        265
# Name: count, dtype: int64
# ---
# Reading in 124.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399874
# 1        126
# Name: count, dtype: int64
# ---
# Reading in 125.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399895
# 1        105
# Name: count, dtype: int64
# ---
# Reading in 126.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399886
# 1        114
# Name: count, dtype: int64
# ---
# Reading in 127.csv
# Shape of the data is: (3690000, 6)
# label_modified
# 0    3689963
# 1         37
# Name: count, dtype: int64
# ---
# Reading in 131.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399892
# 1        108
# Name: count, dtype: int64
# ---
# Reading in 132.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399904
# 1         96
# Name: count, dtype: int64
# ---
# Reading in 133.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399887
# 1        113
# Name: count, dtype: int64
# ---
# Reading in 134.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399904
# 1         96
# Name: count, dtype: int64
# ---
# Reading in 135.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399933
# 1         67
# Name: count, dtype: int64
# ---
# Reading in 136.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399799
# 1        201
# Name: count, dtype: int64
# ---
# Reading in 137.csv
# Shape of the data is: (3690000, 6)
# label_modified
# 0    3689903
# 1         97
# Name: count, dtype: int64
# ---
# Reading in 141.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399825
# 1        175
# Name: count, dtype: int64
# ---
# Reading in 142.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399796
# 1        204
# Name: count, dtype: int64
# ---
# Reading in 143.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399824
# 1        176
# Name: count, dtype: int64
# ---
# Reading in 144.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1877980
# 1         20
# Name: count, dtype: int64
# ---
# Reading in 151.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399902
# 1         98
# Name: count, dtype: int64
# ---
# Reading in 152.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399898
# 1        102
# Name: count, dtype: int64
# ---
# Reading in 153.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399849
# 1        151
# Name: count, dtype: int64
# ---
# Reading in 154.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1877980
# 1         20
# Name: count, dtype: int64
# ---
# Reading in 161.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399830
# 1        170
# Name: count, dtype: int64
# ---
# Reading in 162.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399903
# 1         97
# Name: count, dtype: int64
# ---
# Reading in 163.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399843
# 1        157
# Name: count, dtype: int64
# ---
# Reading in 164.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1877964
# 1         36
# Name: count, dtype: int64
# ---
# Reading in 211.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 212.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399959
# 1         41
# Name: count, dtype: int64
# ---
# Reading in 213.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 214.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399923
# 1         77
# Name: count, dtype: int64
# ---
# Reading in 215.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399975
# 1         25
# Name: count, dtype: int64
# ---
# Reading in 216.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399930
# 1         70
# Name: count, dtype: int64
# ---
# Reading in 217.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399894
# 1        106
# Name: count, dtype: int64
# ---
# Reading in 218.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 219.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399904
# 1         96
# Name: count, dtype: int64
# ---
# Reading in 221.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399963
# 1         37
# Name: count, dtype: int64
# ---
# Reading in 222.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399977
# 1         23
# Name: count, dtype: int64
# ---
# Reading in 223.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399979
# 1         21
# Name: count, dtype: int64
# ---
# Reading in 224.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399947
# 1         53
# Name: count, dtype: int64
# ---
# Reading in 225.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 226.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 227.csv
# Shape of the data is: (3684000, 6)
# label_modified
# 0    3684000
# Name: count, dtype: int64
# ---
# Reading in 231.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399959
# 1         41
# Name: count, dtype: int64
# ---
# Reading in 232.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 233.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 234.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399933
# 1         67
# Name: count, dtype: int64
# ---
# Reading in 235.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399938
# 1         62
# Name: count, dtype: int64
# ---
# Reading in 236.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 237.csv
# Shape of the data is: (3690000, 6)
# label_modified
# 0    3689962
# 1         38
# Name: count, dtype: int64
# ---
# Reading in 241.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399974
# 1         26
# Name: count, dtype: int64
# ---
# Reading in 242.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399932
# 1         68
# Name: count, dtype: int64
# ---
# Reading in 243.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399877
# 1        123
# Name: count, dtype: int64
# ---
# Reading in 244.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1878000
# Name: count, dtype: int64
# ---
# Reading in 251.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399923
# 1         77
# Name: count, dtype: int64
# ---
# Reading in 252.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399959
# 1         41
# Name: count, dtype: int64
# ---
# Reading in 253.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 254.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1878000
# Name: count, dtype: int64
# ---
# Reading in 261.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 262.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399978
# 1         22
# Name: count, dtype: int64
# ---
# Reading in 263.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399967
# 1         33
# Name: count, dtype: int64
# ---
# Reading in 264.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1878000
# Name: count, dtype: int64
# ---
# Reading in 311.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399906
# 1         94
# Name: count, dtype: int64
# ---
# Reading in 312.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399952
# 1         48
# Name: count, dtype: int64
# ---
# Reading in 313.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399901
# 1         99
# Name: count, dtype: int64
# ---
# Reading in 314.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399957
# 1         43
# Name: count, dtype: int64
# ---
# Reading in 315.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399889
# 1        111
# Name: count, dtype: int64
# ---
# Reading in 316.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399819
# 1        181
# Name: count, dtype: int64
# ---
# Reading in 317.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399956
# 1         44
# Name: count, dtype: int64
# ---
# Reading in 318.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399959
# 1         41
# Name: count, dtype: int64
# ---
# Reading in 319.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399950
# 1         50
# Name: count, dtype: int64
# ---
# Reading in 321.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399891
# 1        109
# Name: count, dtype: int64
# ---
# Reading in 322.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399911
# 1         89
# Name: count, dtype: int64
# ---
# Reading in 323.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399836
# 1        164
# Name: count, dtype: int64
# ---
# Reading in 324.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399943
# 1         57
# Name: count, dtype: int64
# ---
# Reading in 325.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399901
# 1         99
# Name: count, dtype: int64
# ---
# Reading in 326.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399779
# 1        221
# Name: count, dtype: int64
# ---
# Reading in 327.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399812
# 1        188
# Name: count, dtype: int64
# ---
# Reading in 328.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399874
# 1        126
# Name: count, dtype: int64
# ---
# Reading in 329.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399886
# 1        114
# Name: count, dtype: int64
# ---
# Reading in 331.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399858
# 1        142
# Name: count, dtype: int64
# ---
# Reading in 332.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399818
# 1        182
# Name: count, dtype: int64
# ---
# Reading in 333.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399646
# 1        354
# Name: count, dtype: int64
# ---
# Reading in 334.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399723
# 1        277
# Name: count, dtype: int64
# ---
# Reading in 335.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399782
# 1        218
# Name: count, dtype: int64
# ---
# Reading in 336.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399924
# 1         76
# Name: count, dtype: int64
# ---
# Reading in 337.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399843
# 1        157
# Name: count, dtype: int64
# ---
# Reading in 338.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399922
# 1         78
# Name: count, dtype: int64
# ---
# Reading in 339.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399962
# 1         38
# Name: count, dtype: int64
# ---
# Reading in 341.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399955
# 1         45
# Name: count, dtype: int64
# ---
# Reading in 342.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399844
# 1        156
# Name: count, dtype: int64
# ---
# Reading in 343.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399976
# 1         24
# Name: count, dtype: int64
# ---
# Reading in 344.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1877980
# 1         20
# Name: count, dtype: int64
# ---
# Reading in 351.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399964
# 1         36
# Name: count, dtype: int64
# ---
# Reading in 352.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399962
# 1         38
# Name: count, dtype: int64
# ---
# Reading in 353.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399970
# 1         30
# Name: count, dtype: int64
# ---
# Reading in 354.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1877957
# 1         43
# Name: count, dtype: int64
# ---
# Reading in 361.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399868
# 1        132
# Name: count, dtype: int64
# ---
# Reading in 362.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399894
# 1        106
# Name: count, dtype: int64
# ---
# Reading in 363.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399837
# 1        163
# Name: count, dtype: int64
# ---
# Reading in 364.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1877914
# 1         86
# Name: count, dtype: int64
# ---
# Reading in 411.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399848
# 1        152
# Name: count, dtype: int64
# ---
# Reading in 412.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399700
# 1        300
# Name: count, dtype: int64
# ---
# Reading in 413.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399472
# 1        528
# Name: count, dtype: int64
# ---
# Reading in 414.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399843
# 1        157
# Name: count, dtype: int64
# ---
# Reading in 415.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399723
# 1        277
# Name: count, dtype: int64
# ---
# Reading in 416.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399453
# 1        547
# Name: count, dtype: int64
# ---
# Reading in 417.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399475
# 1        525
# Name: count, dtype: int64
# ---
# Reading in 418.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399302
# 1        698
# Name: count, dtype: int64
# ---
# Reading in 419.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399742
# 1        258
# Name: count, dtype: int64
# ---
# Reading in 421.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399637
# 1        363
# Name: count, dtype: int64
# ---
# Reading in 422.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399343
# 1        657
# Name: count, dtype: int64
# ---
# Reading in 423.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399931
# 1         69
# Name: count, dtype: int64
# ---
# Reading in 424.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399759
# 1        241
# Name: count, dtype: int64
# ---
# Reading in 425.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399557
# 1        443
# Name: count, dtype: int64
# ---
# Reading in 426.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399678
# 1        322
# Name: count, dtype: int64
# ---
# Reading in 427.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399786
# 1        214
# Name: count, dtype: int64
# ---
# Reading in 428.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399539
# 1        461
# Name: count, dtype: int64
# ---
# Reading in 429.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399845
# 1        155
# Name: count, dtype: int64
# ---
# Reading in 431.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399770
# 1        230
# Name: count, dtype: int64
# ---
# Reading in 432.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399729
# 1        271
# Name: count, dtype: int64
# ---
# Reading in 433.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399835
# 1        165
# Name: count, dtype: int64
# ---
# Reading in 434.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399981
# 1         19
# Name: count, dtype: int64
# ---
# Reading in 435.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399765
# 1        235
# Name: count, dtype: int64
# ---
# Reading in 436.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399600
# 1        400
# Name: count, dtype: int64
# ---
# Reading in 437.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399727
# 1        273
# Name: count, dtype: int64
# ---
# Reading in 438.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399431
# 1        569
# Name: count, dtype: int64
# ---
# Reading in 439.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399815
# 1        185
# Name: count, dtype: int64
# ---
# Reading in 441.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399880
# 1        120
# Name: count, dtype: int64
# ---
# Reading in 442.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399969
# 1         31
# Name: count, dtype: int64
# ---
# Reading in 443.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399776
# 1        224
# Name: count, dtype: int64
# ---
# Reading in 444.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399779
# 1        221
# Name: count, dtype: int64
# ---
# Reading in 445.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399919
# 1         81
# Name: count, dtype: int64
# ---
# Reading in 446.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399850
# 1        150
# Name: count, dtype: int64
# ---
# Reading in 447.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399932
# 1         68
# Name: count, dtype: int64
# ---
# Reading in 448.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399876
# 1        124
# Name: count, dtype: int64
# ---
# Reading in 449.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399963
# 1         37
# Name: count, dtype: int64
# ---
# Reading in 451.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399960
# 1         40
# Name: count, dtype: int64
# ---
# Reading in 452.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399941
# 1         59
# Name: count, dtype: int64
# ---
# Reading in 453.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399904
# 1         96
# Name: count, dtype: int64
# ---
# Reading in 454.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399838
# 1        162
# Name: count, dtype: int64
# ---
# Reading in 455.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399861
# 1        139
# Name: count, dtype: int64
# ---
# Reading in 456.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399917
# 1         83
# Name: count, dtype: int64
# ---
# Reading in 457.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399899
# 1        101
# Name: count, dtype: int64
# ---
# Reading in 458.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399791
# 1        209
# Name: count, dtype: int64
# ---
# Reading in 459.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399604
# 1        396
# Name: count, dtype: int64
# ---
# Reading in 461.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399980
# 1         20
# Name: count, dtype: int64
# ---
# Reading in 462.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399732
# 1        268
# Name: count, dtype: int64
# ---
# Reading in 463.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399900
# 1        100
# Name: count, dtype: int64
# ---
# Reading in 464.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399707
# 1        293
# Name: count, dtype: int64
# ---
# Reading in 465.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399770
# 1        230
# Name: count, dtype: int64
# ---
# Reading in 466.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399664
# 1        336
# Name: count, dtype: int64
# ---
# Reading in 467.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 511.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399603
# 1        397
# Name: count, dtype: int64
# ---
# Reading in 512.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399718
# 1        282
# Name: count, dtype: int64
# ---
# Reading in 513.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399861
# 1        139
# Name: count, dtype: int64
# ---
# Reading in 514.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399958
# 1         42
# Name: count, dtype: int64
# ---
# Reading in 515.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399854
# 1        146
# Name: count, dtype: int64
# ---
# Reading in 516.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399684
# 1        316
# Name: count, dtype: int64
# ---
# Reading in 517.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399769
# 1        231
# Name: count, dtype: int64
# ---
# Reading in 518.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399814
# 1        186
# Name: count, dtype: int64
# ---
# Reading in 519.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399920
# 1         80
# Name: count, dtype: int64
# ---
# Reading in 521.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399848
# 1        152
# Name: count, dtype: int64
# ---
# Reading in 522.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399800
# 1        200
# Name: count, dtype: int64
# ---
# Reading in 523.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399781
# 1        219
# Name: count, dtype: int64
# ---
# Reading in 524.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399723
# 1        277
# Name: count, dtype: int64
# ---
# Reading in 525.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399756
# 1        244
# Name: count, dtype: int64
# ---
# Reading in 526.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399779
# 1        221
# Name: count, dtype: int64
# ---
# Reading in 527.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399754
# 1        246
# Name: count, dtype: int64
# ---
# Reading in 528.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399774
# 1        226
# Name: count, dtype: int64
# ---
# Reading in 529.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399694
# 1        306
# Name: count, dtype: int64
# ---
# Reading in 531.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399977
# 1         23
# Name: count, dtype: int64
# ---
# Reading in 532.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399780
# 1        220
# Name: count, dtype: int64
# ---
# Reading in 533.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399873
# 1        127
# Name: count, dtype: int64
# ---
# Reading in 534.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399842
# 1        158
# Name: count, dtype: int64
# ---
# Reading in 535.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399833
# 1        167
# Name: count, dtype: int64
# ---
# Reading in 536.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399935
# 1         65
# Name: count, dtype: int64
# ---
# Reading in 537.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399951
# 1         49
# Name: count, dtype: int64
# ---
# Reading in 538.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399921
# 1         79
# Name: count, dtype: int64
# ---
# Reading in 539.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399899
# 1        101
# Name: count, dtype: int64
# ---
# Reading in 541.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399810
# 1        190
# Name: count, dtype: int64
# ---
# Reading in 542.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399897
# 1        103
# Name: count, dtype: int64
# ---
# Reading in 543.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399942
# 1         58
# Name: count, dtype: int64
# ---
# Reading in 544.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399736
# 1        264
# Name: count, dtype: int64
# ---
# Reading in 545.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399786
# 1        214
# Name: count, dtype: int64
# ---
# Reading in 546.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399869
# 1        131
# Name: count, dtype: int64
# ---
# Reading in 547.csv
# Shape of the data is: (3690000, 6)
# label_modified
# 0    3689905
# 1         95
# Name: count, dtype: int64
# ---
# Reading in 551.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399883
# 1        117
# Name: count, dtype: int64
# ---
# Reading in 552.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399811
# 1        189
# Name: count, dtype: int64
# ---
# Reading in 553.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399899
# 1        101
# Name: count, dtype: int64
# ---
# Reading in 554.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399979
# 1         21
# Name: count, dtype: int64
# ---
# Reading in 555.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399911
# 1         89
# Name: count, dtype: int64
# ---
# Reading in 556.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399899
# 1        101
# Name: count, dtype: int64
# ---
# Reading in 557.csv
# Shape of the data is: (3684000, 6)
# label_modified
# 0    3683951
# 1         49
# Name: count, dtype: int64
# ---
# Reading in 561.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399921
# 1         79
# Name: count, dtype: int64
# ---
# Reading in 562.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399886
# 1        114
# Name: count, dtype: int64
# ---
# Reading in 563.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399917
# 1         83
# Name: count, dtype: int64
# ---
# Reading in 564.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399935
# 1         65
# Name: count, dtype: int64
# ---
# Reading in 565.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399962
# 1         38
# Name: count, dtype: int64
# ---
# Reading in 566.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399941
# 1         59
# Name: count, dtype: int64
# ---
# Reading in 567.csv
# Shape of the data is: (3690000, 6)
# label_modified
# 0    3689982
# 1         18
# Name: count, dtype: int64
# ---
# Reading in 571.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399961
# 1         39
# Name: count, dtype: int64
# ---
# Reading in 572.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399962
# 1         38
# Name: count, dtype: int64
# ---
# Reading in 573.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 574.csv
# Shape of the data is: (1878000, 6)
# label_modified
# 0    1877959
# 1         41
# Name: count, dtype: int64
# ---
# Reading in 581.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 582.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399982
# 1         18
# Name: count, dtype: int64
# ---
# Reading in 2110.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399981
# 1         19
# Name: count, dtype: int64
# ---
# Reading in 2111.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---
# Reading in 3110.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5400000
# Name: count, dtype: int64
# ---
# Reading in 3111.csv
# Shape of the data is: (90000, 6)
# label_modified
# 0    90000
# Name: count, dtype: int64
# ---
# Reading in 3210.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399898
# 1        102
# Name: count, dtype: int64
# ---
# Reading in 3211.csv
# Shape of the data is: (66000, 6)
# label_modified
# 0    66000
# Name: count, dtype: int64
# ---
# Reading in 3310.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399920
# 1         80
# Name: count, dtype: int64
# ---
# Reading in 3311.csv
# Shape of the data is: (90000, 6)
# label_modified
# 0    90000
# Name: count, dtype: int64
# ---
# Reading in 4110.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399921
# 1         79
# Name: count, dtype: int64
# ---
# Reading in 4111.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---
# Reading in 4210.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399921
# 1         79
# Name: count, dtype: int64
# ---
# Reading in 4211.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---
# Reading in 4310.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399664
# 1        336
# Name: count, dtype: int64
# ---
# Reading in 4311.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---
# Reading in 4410.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399694
# 1        306
# Name: count, dtype: int64
# ---
# Reading in 4411.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---
# Reading in 4510.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399754
# 1        246
# Name: count, dtype: int64
# ---
# Reading in 4511.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---
# Reading in 5110.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399794
# 1        206
# Name: count, dtype: int64
# ---
# Reading in 5111.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---
# Reading in 5210.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399803
# 1        197
# Name: count, dtype: int64
# ---
# Reading in 5211.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---
# Reading in 5310.csv
# Shape of the data is: (5400000, 6)
# label_modified
# 0    5399886
# 1        114
# Name: count, dtype: int64
# ---
# Reading in 5311.csv
# Shape of the data is: (96000, 6)
# label_modified
# 0    96000
# Name: count, dtype: int64
# ---

# %%
# write into a file
corr_df.to_csv('/content/drive/MyDrive/DISC_Files/spearman_correlations_with_n.csv', index=False)

# %%
# reading in the correlation file - spearman_correlations_with_n.csv
corr_df = pd.read_csv('/content/drive/MyDrive/DISC_Files/spearman_correlations_with_n.csv')
corr_df.head()
# Out:
#    Filename         n1     n2  405 vs 488  488 vs 633  405 vs 633  \
# 0     111.0  5399900.0  100.0    0.184567    0.784595    0.089252
# 1     112.0  5399765.0  235.0    0.184176    0.784328    0.089357
# 2     113.0  5399704.0  296.0    0.183987    0.784685    0.088181
# 3     114.0  5399736.0  264.0    0.183720    0.784697    0.086626
# 4     115.0  5399806.0  194.0    0.183713    0.786922    0.087060
#
#    405 vs 488 (p)  488 vs 633 (p)  405 vs 633 (p)
# 0        0.027519        0.735350       -0.165269
# 1        0.020645        0.810762       -0.135009
# 2        0.238692        0.758045        0.000285
# 3        0.427688        0.505995       -0.152016
# 4        0.384413        0.678779        0.323966

# %%
# print the minimum values of each column
print("Minimum values:")
print(corr_df.min().to_string(float_format="{:.2f}".format))

# print the maximum values of each column
print("\nMaximum values:")
print(corr_df.max().to_string(float_format="{:.2f}".format))
# Out:
# Minimum values:
# Filename           111.00
# n1               66000.00
# n2                   0.00
# 405 vs 488           0.04
# 488 vs 633           0.62
# 405 vs 633          -0.07
# 405 vs 488 (p)      -0.65
# 488 vs 633 (p)      -0.31
# 405 vs 633 (p)      -0.81
#
# Maximum values:
# Filename            5311.00
# n1               5400000.00
# n2                   698.00
# 405 vs 488             0.19
# 488 vs 633             0.80
# 405 vs 633             0.09
# 405 vs 488 (p)         0.95
# 488 vs 633 (p)         0.96
# 405 vs 633 (p)         0.90

# %%
# 405 v 488
# plotting the histogram for 405 vs 488 (p) correlations
sns.histplot(data=corr_df, x='405 vs 488 (p)', kde=True, color='red', label='405 vs 488 (p)')

# plotting the histogram for 405 vs 488 correlations
sns.histplot(data=corr_df, x='405 vs 488', kde=True, color='blue', label='405 vs 488')

# setting labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Correlation Values')
plt.grid(True)

# adding legend
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 488 vs 633
# plotting the histogram for 488 vs 633 (p) correlations
sns.histplot(data=corr_df, x='488 vs 633 (p)', kde=True, color='red', label='488 vs 633 (p)')

# plotting the histogram for 488 vs 633 correlations
sns.histplot(data=corr_df, x='488 vs 633', kde=True, color='blue', label='488 vs 633')

# setting labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Correlation Values')
plt.grid(True)

# adding legend
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 405 vs 633
# plotting the histogram for 405 vs 633 (p) correlations
sns.histplot(data=corr_df, x='405 vs 633 (p)', kde=True, color='red', label='405 vs 633 (p)')

# plotting the histogram for 405 vs 633 correlations
sns.histplot(data=corr_df, x='405 vs 633', kde=True, color='blue', label='405 vs 633')

# setting labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of Correlation Values')
plt.grid(True)

# adding legend
plt.legend()

plt.tight_layout()
plt.show()
